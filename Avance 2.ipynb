# %%
pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\invitadolaptop\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.25.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: redis>=3.5.3 in c:\users\invitadolaptop\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spotipy) (5.2.1)
# Requirement already satisfied: requests>=2.25.0 in c:\users\invitadolaptop\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\invitadolaptop\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spotipy) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\invitadolaptop\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.25.0->spotipy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\invitadolaptop\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\invitadolaptop\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.25.0->spotipy) (2025.1.31)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\InvitadoLaptop\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\invitadolaptop\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.67.1)
# Requirement already satisfied: colorama in c:\users\invitadolaptop\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\InvitadoLaptop\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import spotipy
import pandas as pd
import tqdm
import requests
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
CLIENT_ID = 'e89a20fa9f524fbe91a34ed52c346ce5'
CLIENT_SECRET = '5b776dd228714f9cad9716a07a6d6a25'

# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
artistas_list = ['Ke Personajes', 'Ariana Grande', 'Linkin Park', 'Amelie lens', 'Maneskin']

album_data = []

# %%
for artista_nombre in tqdm.tqdm(artistas_list, desc='Obteniendo álbumes de artistas:'):
    resultados = sp.search(q=f'artist:{artista_nombre}', type='album')

    for album in resultados['albums']['items']:
        nombre_album = album['name']
        fecha_lanzamiento = album['release_date']

        artistas = [artist['name'] for artist in album['artists']]
        artista_principal = artistas[0] if artistas else "Artista no disponible"

        genero = "Género no disponible"
        artista_id = None  # Inicializa artista_id fuera del bloque if
        if album['artists']:
            artista_id = album['artists'][0]['id']  # Ahora artista_id tiene el ID del artista
            artista_info = sp.artist(artista_id)
            generos_artista = artista_info.get('genres', [])
            if generos_artista:
                genero = generos_artista[0]

        año_lanzamiento = fecha_lanzamiento[:4]  # Obtiene solo el año

        # Verifica si el año está en el rango deseado
        if 2019 <= int(año_lanzamiento) <= 2024:
            album_info = {
                "ID": artista_id,  # Usa artista_id en lugar de album['id']
                "Artista": artista_principal,
                "Género": genero,
                "Tipo": "Álbum",
                "Nombre del Álbum": nombre_album,
                "Año de lanzamiento": año_lanzamiento
            }

            album_data.append(album_info)

df_albums = pd.DataFrame(album_data)
df_albums
# Out:
# Obteniendo álbumes de artistas:: 100%|██████████| 5/5 [00:05<00:00,  1.04s/it]
#                         ID        Artista                Género   Tipo  \
# 0   06Q5VlSAku57lFzyME3HrM  Ke Personajes                cumbia  Álbum
# 1   06Q5VlSAku57lFzyME3HrM  Ke Personajes                cumbia  Álbum
# 2   06Q5VlSAku57lFzyME3HrM  Ke Personajes                cumbia  Álbum
# 3   06Q5VlSAku57lFzyME3HrM  Ke Personajes                cumbia  Álbum
# 4   06Q5VlSAku57lFzyME3HrM  Ke Personajes                cumbia  Álbum
# 5   06Q5VlSAku57lFzyME3HrM  Ke Personajes                cumbia  Álbum
# 6   06Q5VlSAku57lFzyME3HrM  Ke Personajes                cumbia  Álbum
# 7   06Q5VlSAku57lFzyME3HrM  Ke Personajes                cumbia  Álbum
# 8   06Q5VlSAku57lFzyME3HrM  Ke Personajes                cumbia  Álbum
# 9   66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande                   pop  Álbum
# 10  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande                   pop  Álbum
# 11  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande                   pop  Álbum
# 12  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande                   pop  Álbum
# 13  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande                   pop  Álbum
# 14  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande                   pop  Álbum
# 15  6XyY86QOPPrYVGvF9ch6wz    Linkin Park              nu metal  Álbum
# 16  6XyY86QOPPrYVGvF9ch6wz    Linkin Park              nu metal  Álbum
# 17  6XyY86QOPPrYVGvF9ch6wz    Linkin Park              nu metal  Álbum
# 18  6XyY86QOPPrYVGvF9ch6wz    Linkin Park              nu metal  Álbum
# 19  5Ho1vKl1Uz8bJlk4vbmvmf    Amelie Lens                techno  Álbum
# 20  5Ho1vKl1Uz8bJlk4vbmvmf    Amelie Lens                techno  Álbum
# 21  5Ho1vKl1Uz8bJlk4vbmvmf    Amelie Lens                techno  Álbum
# 22  5Ho1vKl1Uz8bJlk4vbmvmf    Amelie Lens                techno  Álbum
# 23  5Ho1vKl1Uz8bJlk4vbmvmf    Amelie Lens                techno  Álbum
# 24  5Ho1vKl1Uz8bJlk4vbmvmf    Amelie Lens                techno  Álbum
# 25  5Ho1vKl1Uz8bJlk4vbmvmf    Amelie Lens                techno  Álbum
# 26  5Ho1vKl1Uz8bJlk4vbmvmf    Amelie Lens                techno  Álbum
# 27  5Ho1vKl1Uz8bJlk4vbmvmf    Amelie Lens                techno  Álbum
# 28  0lAWpj5szCSwM4rUMHYmrr       Måneskin  Género no disponible  Álbum
# 29  0lAWpj5szCSwM4rUMHYmrr       Måneskin  Género no disponible  Álbum
# 30  0lAWpj5szCSwM4rUMHYmrr       Måneskin  Género no disponible  Álbum
# 31  0lAWpj5szCSwM4rUMHYmrr       Måneskin  Género no disponible  Álbum
# 32  0lAWpj5szCSwM4rUMHYmrr       Måneskin  Género no disponible  Álbum
# 33  0lAWpj5szCSwM4rUMHYmrr       Måneskin  Género no disponible  Álbum
# 34  0lAWpj5szCSwM4rUMHYmrr       Måneskin  Género no disponible  Álbum
# 35  0lAWpj5szCSwM4rUMHYmrr       Måneskin  Género no disponible  Álbum
#
#                                      Nombre del Álbum Año de lanzamiento
# 0                             Pobre Corazón (En Vivo)               2023
# 1                              Adiós Amor / Oye Mujer               2020
# 2           Si No Te Tengo / Ángel / Aquello Que Pasó               2021
# 3                                        Otro Día Más               2021
# 4                                          Cómo estás               2019
# 5                                        Como la Flor               2022
# 6                                   Entre Beso y Beso               2023
# 7                   Entre el Odio y el Amor (En Vivo)               2024
# 8                                   Intento (En Vivo)               2024
# 9                                    eternal sunshine               2024
# 10                                      thank u, next               2019
# 11                                          Positions               2020
# 12                                   eternal sunshine               2024
# 13                                       Stuck with U               2020
# 14                                 Positions (Deluxe)               2021
# 15                                          From Zero               2024
# 16                              The Emptiness Machine               2024
# 17                                 Heavy Is the Crown               2024
# 18                   Meteora 20th Anniversary Edition               2023
# 19                                    Falling For You               2024
# 20                                            Breathe               2024
# 21                                            Feel It               2023
# 22                                         You and Me               2023
# 23  Global Underground #44: Amelie Lens - Antwerp ...               2022
# 24         Underneath The Strobelights (Exhale VA005)               2024
# 25  Global Underground #44: Amelie Lens - Antwerp ...               2022
# 26               fabric presents Amelie Lens (DJ Mix)               2019
# 27                                         Hypnotized               2019
# 28                              Teatro d'ira - Vol. I               2021
# 29                                              RUSH!               2023
# 30                              RUSH! (ARE U COMING?)               2023
# 31                                              RUSH!               2023
# 32                                      THE LONELIEST               2022
# 33                         GOSSIP (feat. Tom Morello)               2023
# 34                                         SUPERMODEL               2022
# 35                                           MAMMAMIA               2021

# %%
API_KEY = "d43d3344b1962fd39c8e7dd314d2296c"  # Reemplaza con tu clave de Last.fm
ARTISTS = ['Ke Personajes', 'Ariana Grande', 'Linkin Park', 'Amelie lens', 'Maneskin']  # Lista de artistas

artist_data = []

def get_artist_info(artist):
    url = f"http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist={artist}&api_key={API_KEY}&format=json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if "artist" in data:
            artist_info = {
                "ID": artista_id,
                "Artista": data['artist']['name'],
                "Biografía": data['artist']['bio']['summary'],  
                "Oyentes": data['artist']['stats']['listeners'],  
                "Reproducciones": data['artist']['stats']['playcount'],  
                "URL": data['artist']['url']
            }
            artist_data.append(artist_info)
        else:
            print(f"No se encontró el artista: {artist}")
    else:
        print(f"Error en la solicitud para {artist}: {response.status_code}")

# Llama a la función para cada artista en la lista
for artist in ARTISTS:
    get_artist_info(artist)

# Crea el DataFrame después de recopilar todos los datos
df_artist = pd.DataFrame(artist_data)

df_artist #Cambiar csv antes
# Out:
#                        ID        Artista  \
# 0  0lAWpj5szCSwM4rUMHYmrr  Ke personajes
# 1  0lAWpj5szCSwM4rUMHYmrr  Ariana Grande
# 2  0lAWpj5szCSwM4rUMHYmrr    Linkin Park
# 3  0lAWpj5szCSwM4rUMHYmrr    Amelie Lens
# 4  0lAWpj5szCSwM4rUMHYmrr       Maneskin
#
#                                            Biografía  Oyentes Reproducciones  \
# 0   <a href="https://www.last.fm/music/Ke+persona...    42108        1030516
# 1  Ariana Grande-Butera, better known professiona...  3736247      805093248
# 2  Linkin Park is an American nu-metal band from ...  5864614      523786563
# 3  Amelie Lens (born 31 May 1990) is a Belgian el...   121367        1158705
# 4  Måneskin is an Italian rock band formed in Rom...     5113          82605
#
#                                        URL
# 0  https://www.last.fm/music/Ke+personajes
# 1  https://www.last.fm/music/Ariana+Grande
# 2    https://www.last.fm/music/Linkin+Park
# 3    https://www.last.fm/music/Amelie+Lens
# 4       https://www.last.fm/music/Maneskin

# %%
similar_artist_data = []
def get_similar_artists(artist):
    url_similar = f"http://ws.audioscrobbler.com/2.0/?method=artist.getsimilar&artist={artist}&api_key={API_KEY}&format=json"
    response_similar = requests.get(url_similar)
    if response_similar.status_code == 200:
        data_similar = response_similar.json()
        if "similarartists" in data_similar and "artist" in data_similar["similarartists"]:
            for similar_artist in data_similar['similarartists']['artist']:
                similar_artist_data.append({
                    "ID": artista_id,
                    "Artista Original": artist,
                    "Artista Similar": similar_artist['name'],
                    "Coincidencia": similar_artist['match']
                })
        else:
            print(f"No se encontraron artistas similares para {artist}.")
    else:
        print(f"Error en la solicitud de artistas similares para {artist}: {response_similar.status_code}")
# Llama a la función para cada artista en la lista
for artist in ARTISTS:
    get_similar_artists(artist)
# Crea el DataFrame después de recopilar todos los datos
df_similar_artist = pd.DataFrame(similar_artist_data)
df_similar_artist
# Out:
#                          ID Artista Original           Artista Similar  \
# 0    0lAWpj5szCSwM4rUMHYmrr    Ke Personajes               La T y la M
# 1    0lAWpj5szCSwM4rUMHYmrr    Ke Personajes                    Ráfaga
# 2    0lAWpj5szCSwM4rUMHYmrr    Ke Personajes              Damas Gratis
# 3    0lAWpj5szCSwM4rUMHYmrr    Ke Personajes              Los Palmeras
# 4    0lAWpj5szCSwM4rUMHYmrr    Ke Personajes              Leo Mattioli
# ..                      ...              ...                       ...
# 495  0lAWpj5szCSwM4rUMHYmrr         Maneskin                 Inioranti
# 496  0lAWpj5szCSwM4rUMHYmrr         Maneskin              Luca Bacconi
# 497  0lAWpj5szCSwM4rUMHYmrr         Maneskin              Marco Notari
# 498  0lAWpj5szCSwM4rUMHYmrr         Maneskin  La ragazza dello Sputnik
# 499  0lAWpj5szCSwM4rUMHYmrr         Maneskin                    Ze Hop
#
#     Coincidencia
# 0              1
# 1       0.517295
# 2       0.504201
# 3       0.464110
# 4       0.459296
# ..           ...
# 495     0.081652
# 496     0.081652
# 497     0.081652
# 498     0.081652
# 499     0.081652
#
# [500 rows x 4 columns]

# %%
df_albums.to_csv("albums.csv")

# %%
df_artist.to_csv("artist.csv")

# %%
df_similar_artist.to_csv("similar_artist.csv")

# %%
import mysql.connector
from mysql.connector import errorcode
import pandas as pd

# %%
try:
  cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='northwind')

except mysql.connector.Error as err:

  if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
    print("Something is wrong with your user name or password")
  
  
  elif err.errno == errorcode.ER_BAD_DB_ERROR:
    print("Database does not exist")
  
  
  else:
    print(err)
else:
  cnx.close()

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1')


mycursor = cnx.cursor()
try:
    mycursor.execute("CREATE DATABASE music_stream_proyecto")
    print(mycursor)
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
# Out:
# MySQLCursor: CREATE DATABASE music_stream_proyecto

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='music_stream_proyecto')


mycursor = cnx.cursor()
try:
    mycursor.execute("""
    CREATE TABLE artistas_similares(
        ID VARCHAR(50), 
        Artista_Original VARCHAR(200), 
        Artista_Similar VARCHAR(200), 
        Coincidencia FLOAT
    )
""")

    mycursor.execute("""
    CREATE TABLE Albumes(
        id_album VARCHAR(100), 
        titulo_album VARCHAR(75), 
        año_lanzamiento YEAR, 
        id_artista INT
    )
""")
    
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
# Out:
# MySQLCursor: CREATE TABLE album_artista( Artista_ID V..

# %%
pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\invitadolaptop\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.0.38)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\invitadolaptop\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\invitadolaptop\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\InvitadoLaptop\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+mysqlconnector://root:AlumnaAdalab@127.0.0.1/music_stream_proyecto')

# %%
df_albums.to_sql('album_artista', engine, if_exists='replace', index=False)
print("Datos insertados correctamente.")
# Out:
# Datos insertados correctamente.
